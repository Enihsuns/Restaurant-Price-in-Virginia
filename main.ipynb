# %% [markdown]
# # Machine Learning For Local Restaurant Price Assessment And Prediction
#
# ## 1. Generate pandas.DataFrame from json
#
# In this section, we generate dataframe from the data we collected using Yelp API. Explanation of each features can be found at [https://www.yelp.com/developers/documentation/v3/business_search].

# %%
import pandas as pd
import json

# Read data
with open('./Dataset/restaurants_VA.json', encoding = 'utf8') as inFile:
    data = json.load(inFile)
    
data = pd.DataFrame.from_dict(data)
display(data.head(5))

print("Total {0} samples".format(len(data)))
# Out:
#                                       alias  \
# 0                 the-dutch-treat-rose-hill
# 1                a-better-burger-jonesville
# 2                    el-castillo-jonesville
# 3              el-centenario-pennington-gap
# 4  rubys-country-steak-house-pennington-gap
#
#                                           categories  \
# 0  [{'alias': 'delis', 'title': 'Delis'}, {'alias...
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'restaurants', 'title': 'Restaurant...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 36.6903325, 'longitude': -83.3104...  (276) 445-4024
# 1   {'latitude': 36.689639, 'longitude': -83.108766}  (276) 346-6768
# 2  {'latitude': 36.7263373464484, 'longitude': -8...  (276) 346-4000
# 3  {'latitude': 36.7602500915527, 'longitude': -8...  (276) 546-0044
# 4  {'latitude': 36.7624955624342, 'longitude': -8...  (276) 546-6900
#
#        distance                      id  \
# 0  19538.084959  rd8oYQOtyc4LxjPQp8Muvw
# 1  34871.790634  bwCj2AcoOroZfCTxb6rCcg
# 2  37317.843873  S9S9kFJSkmfpbjFForCWLQ
# 3  36034.813254  XFksdPFZhPHk458C0pl0Cg
# 4  38271.262707  AsZk7i1UyQSElluN_ixSPQ
#
#                                            image_url  is_closed  \
# 0                                                         False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/3KS3Xs...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/NGC_GJ...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/G5XFTv...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/n6JFx4...      False
#
#                                             location  \
# 0  {'address1': '21332 Wilderness Rd', 'address2'...
# 1  {'address1': '33739 Main St', 'address2': 'Ste...
# 2  {'address1': '236 Trade Center Ln', 'address2'...
# 3  {'address1': '930 E Morgan Ave', 'address2': N...
# 4  {'address1': '131 Industrial Dr', 'address2': ...
#
#                         name         phone price  rating  review_count  \
# 0            The Dutch Treat  +12764454024   NaN     5.0             2
# 1            A Better Burger  +12763466768    $$     3.5             6
# 2                El Castillo  +12763464000     $     4.0             2
# 3              El Centenario  +12765460044   NaN     5.0             3
# 4  Rubys Country Steak House  +12765466900   NaN     3.5             2
#
#   transactions                                                url
# 0           []  https://www.yelp.com/biz/the-dutch-treat-rose-...
# 1           []  https://www.yelp.com/biz/a-better-burger-jones...
# 2           []  https://www.yelp.com/biz/el-castillo-jonesvill...
# 3           []  https://www.yelp.com/biz/el-centenario-penning...
# 4           []  https://www.yelp.com/biz/rubys-country-steak-h...
# Total 6413 samples

# %% [markdown]
# In this step, we drop the not very useful features and extract some important features from a json format column.

# %%
# drop columns: 'alias', 'is_closed', 'url', 'transactions', 'phone', 'display_phone', 'distance' 
data = data.drop(columns=['alias', 'is_closed', 'url', 'transactions', 'phone', 'display_phone', 'distance'])

# extract latitude and longitude values
coords = data['coordinates'].tolist()
coords_json = str(coords).replace("'", "\"")
df = pd.DataFrame(json.loads(coords_json))
data['latitude'] = df['latitude']
data['longitude'] = df['longitude']

# extract city info
locations = data['location'].tolist()
cities = []
for loc in locations:
    cities.append(loc['city'])
data['city'] = cities

# drop columns: 'coordinates', 'location'
data = data.drop(columns=['coordinates', 'location'])
data.head()
# Out:
#                                           categories                      id  \
# 0  [{'alias': 'delis', 'title': 'Delis'}, {'alias...  rd8oYQOtyc4LxjPQp8Muvw
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...  bwCj2AcoOroZfCTxb6rCcg
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]  S9S9kFJSkmfpbjFForCWLQ
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]  XFksdPFZhPHk458C0pl0Cg
# 4  [{'alias': 'restaurants', 'title': 'Restaurant...  AsZk7i1UyQSElluN_ixSPQ
#
#                                            image_url  \
# 0
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/3KS3Xs...
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/NGC_GJ...
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/G5XFTv...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/n6JFx4...
#
#                         name price  rating  review_count   latitude  \
# 0            The Dutch Treat   NaN     5.0             2  36.690332
# 1            A Better Burger    $$     3.5             6  36.689639
# 2                El Castillo     $     4.0             2  36.726337
# 3              El Centenario   NaN     5.0             3  36.760250
# 4  Rubys Country Steak House   NaN     3.5             2  36.762496
#
#    longitude            city
# 0 -83.310449       Rose Hill
# 1 -83.108766      Jonesville
# 2 -83.099858      Jonesville
# 3 -83.023682  Pennington Gap
# 4 -83.017144  Pennington Gap

# %%
cate_info = data.categories
for cate in cate_info:
    print(cate)
# Out:
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'cheese', 'title': 'Cheese Shops'}, {'alias': 'meats', 'title': 'Meat Shops'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'wraps', 'title': 'Wraps'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'cupcakes', 'title': 'Cupcakes'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'hotdog', 'title': 'Hot Dogs'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]
# [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'cupcakes', 'title': 'Cupcakes'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'salad', 'title': 'Salad'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'buffets', 'title': 'Buffets'}]
# [{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'servicestations', 'title': 'Gas Stations'}, {'alias': 'convenience', 'title': 'Convenience Stores'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'salad', 'title': 'Salad'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'soup', 'title': 'Soup'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'smokehouse', 'title': 'Smokehouse'}, {'alias': 'musicvenues', 'title': 'Music Venues'}]
# [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}, {'alias': 'hotels', 'title': 'Hotels'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# [{'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'desserts', 'title': 'Desserts'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'giftshops', 'title': 'Gift Shops'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'convenience', 'title': 'Convenience Stores'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'pastashops', 'title': 'Pasta Shops'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'smokehouse', 'title': 'Smokehouse'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'soup', 'title': 'Soup'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'buffets', 'title': 'Buffets'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'spas', 'title': 'Day Spas'}, {'alias': 'restaurants', 'title': 'Restaurants'}, {'alias': 'golf', 'title': 'Golf'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]
# [{'alias': 'grocery', 'title': 'Grocery'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'nightlife', 'title': 'Nightlife'}, {'alias': 'hotels', 'title': 'Hotels'}, {'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'hotels', 'title': 'Hotels'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'catering', 'title': 'Caterers'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'soulfood', 'title': 'Soul Food'}]
# [{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'breweries', 'title': 'Breweries'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'soulfood', 'title': 'Soul Food'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'salad', 'title': 'Salad'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'desserts', 'title': 'Desserts'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'pubs', 'title': 'Pubs'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'lounges', 'title': 'Lounges'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'candy', 'title': 'Candy Stores'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'sportgoods', 'title': 'Sporting Goods'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'convenience', 'title': 'Convenience Stores'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hardware', 'title': 'Hardware Stores'}, {'alias': 'grocery', 'title': 'Grocery'}, {'alias': 'convenience', 'title': 'Convenience Stores'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'importedfood', 'title': 'Imported Food'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'buffets', 'title': 'Buffets'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'turkish', 'title': 'Turkish'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'caribbean', 'title': 'Caribbean'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'soulfood', 'title': 'Soul Food'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'pubs', 'title': 'Pubs'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'smokehouse', 'title': 'Smokehouse'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'filipino', 'title': 'Filipino'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'modern_european', 'title': 'Modern European'}]
# [{'alias': 'modern_european', 'title': 'Modern European'}]
# [{'alias': 'filipino', 'title': 'Filipino'}, {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}]
# [{'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'soup', 'title': 'Soup'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'southern', 'title': 'Southern'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'southern', 'title': 'Southern'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'argentine', 'title': 'Argentine'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'gluten_free', 'title': 'Gluten-Free'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'streetvendors', 'title': 'Street Vendors'}, {'alias': 'catering', 'title': 'Caterers'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'ramen', 'title': 'Ramen'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'gastropubs', 'title': 'Gastropubs'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}]
# [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'social_clubs', 'title': 'Social Clubs'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'caribbean', 'title': 'Caribbean'}]
# [{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]
# [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'beerbar', 'title': 'Beer Bar'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'tikibars', 'title': 'Tiki Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'wraps', 'title': 'Wraps'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'breweries', 'title': 'Breweries'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'soup', 'title': 'Soup'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'diners', 'title': 'Diners'}, {'alias': 'convenience', 'title': 'Convenience Stores'}]
# [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'noodles', 'title': 'Noodles'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'creperies', 'title': 'Creperies'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'pastashops', 'title': 'Pasta Shops'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'servicestations', 'title': 'Gas Stations'}, {'alias': 'convenience', 'title': 'Convenience Stores'}, {'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}]
# ...
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'steak', 'title': 'Steakhouses'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'bakeries', 'title': 'Bakeries'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'lebanese', 'title': 'Lebanese'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'french', 'title': 'French'}]
# [{'alias': 'breweries', 'title': 'Breweries'}, {'alias': 'pretzels', 'title': 'Pretzels'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'german', 'title': 'German'}, {'alias': 'modern_european', 'title': 'Modern European'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'peruvian', 'title': 'Peruvian'}]
# [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'salvadoran', 'title': 'Salvadoran'}, {'alias': 'empanadas', 'title': 'Empanadas'}, {'alias': 'tacos', 'title': 'Tacos'}]
# [{'alias': 'brasseries', 'title': 'Brasseries'}, {'alias': 'french', 'title': 'French'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# [{'alias': 'vietnamese', 'title': 'Vietnamese'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'wineries', 'title': 'Wineries'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]
# [{'alias': 'greek', 'title': 'Greek'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'belgian', 'title': 'Belgian'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'wraps', 'title': 'Wraps'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'indpak', 'title': 'Indian'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'raw_food', 'title': 'Live/Raw Food'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'salad', 'title': 'Salad'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'beerbar', 'title': 'Beer Bar'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]
# [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'taiwanese', 'title': 'Taiwanese'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}]
# [{'alias': 'peruvian', 'title': 'Peruvian'}, {'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'vietnamese', 'title': 'Vietnamese'}]
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}]
# [{'alias': 'vietnamese', 'title': 'Vietnamese'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'halal', 'title': 'Halal'}]
# [{'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'indpak', 'title': 'Indian'}]
# [{'alias': 'indpak', 'title': 'Indian'}]
# [{'alias': 'korean', 'title': 'Korean'}, {'alias': 'cajun', 'title': 'Cajun/Creole'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'burmese', 'title': 'Burmese'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'hotdog', 'title': 'Hot Dogs'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'poke', 'title': 'Poke'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'hawaiian', 'title': 'Hawaiian'}]
# [{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'mediterranean', 'title': 'Mediterranean'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'korean', 'title': 'Korean'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]
# [{'alias': 'salvadoran', 'title': 'Salvadoran'}]
# [{'alias': 'indpak', 'title': 'Indian'}]
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'salad', 'title': 'Salad'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'indpak', 'title': 'Indian'}]
# [{'alias': 'cuban', 'title': 'Cuban'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'vietnamese', 'title': 'Vietnamese'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'kebab', 'title': 'Kebab'}]
# [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'southern', 'title': 'Southern'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'ramen', 'title': 'Ramen'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]
# [{'alias': 'wine_bars', 'title': 'Wine Bars'}, {'alias': 'restaurants', 'title': 'Restaurants'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'burgers', 'title': 'Burgers'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'importedfood', 'title': 'Imported Food'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'servicestations', 'title': 'Gas Stations'}, {'alias': 'convenience', 'title': 'Convenience Stores'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}]
# [{'alias': 'german', 'title': 'German'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'fishnchips', 'title': 'Fish & Chips'}]
# [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'latin', 'title': 'Latin American'}]
# [{'alias': 'thai', 'title': 'Thai'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'catering', 'title': 'Caterers'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'greek', 'title': 'Greek'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'diners', 'title': 'Diners'}]
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'british', 'title': 'British'}, {'alias': 'pubs', 'title': 'Pubs'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'caribbean', 'title': 'Caribbean'}]
# [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]
# [{'alias': 'wraps', 'title': 'Wraps'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]
# [{'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'french', 'title': 'French'}]
# [{'alias': 'salad', 'title': 'Salad'}, {'alias': 'peruvian', 'title': 'Peruvian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'bars', 'title': 'Bars'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
# [{'alias': 'mexican', 'title': 'Mexican'}]
# [{'alias': 'chinese', 'title': 'Chinese'}]
# [{'alias': 'kebab', 'title': 'Kebab'}, {'alias': 'persian', 'title': 'Persian/Iranian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}]
# [{'alias': 'seafood', 'title': 'Seafood'}]
# [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'tobaccoshops', 'title': 'Tobacco Shops'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# [{'alias': 'farmersmarket', 'title': 'Farmers Market'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'delis', 'title': 'Delis'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodstands', 'title': 'Food Stands'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'gastropubs', 'title': 'Gastropubs'}]
# [{'alias': 'newamerican', 'title': 'American (New)'}]
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]
# [{'alias': 'asianfusion', 'title': 'Asian Fusion'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'italian', 'title': 'Italian'}]
# [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'diners', 'title': 'Diners'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}]
# [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'cafes', 'title': 'Cafes'}]
# [{'alias': 'breweries', 'title': 'Breweries'}, {'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]
# [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'bbq', 'title': 'Barbeque'}]
# [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]
# [{'alias': 'foodstands', 'title': 'Food Stands'}]
# [{'alias': 'pizza', 'title': 'Pizza'}]
